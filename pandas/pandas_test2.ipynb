# %% [markdown]
# # 데이터 전처리 테스트
# 앞서 작성되어 있는 데이터 전처리 이론을 참고하여 직접 완성해 보세요.
#
# 추가(선택) : 작성하신 코드에 주석을 직접 달면서 완성하시면 시간은 오래걸리지만 코드 흐름을 파악기에 좋습니다.

# %% [markdown]
# ### 예제문제 : 주민등록 인구통계 데이터 가져오기

# %% [markdown]
# ### 예제문제 : 필요한 열만 선택해서 데이터프레임 만들기

# %% [markdown]
# ### 예제문제 : 열 이름 정제하기

# %% [markdown]
# ### 예제문제 : 결측치 확인

# %% [markdown]
# ### 예제문제 : 문자열로 저장된 숫자 데이터를 숫자로 변환

# %% [markdown]
# ### 예제문제 : 총인구수 기준 상위 10개 행정동 보기

# %% [markdown]
# ### 예제문제 : 상위 10개 행정동 총인구수 시각화
